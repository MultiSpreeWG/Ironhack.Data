# %%
#import tools & Data
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
import sqlalchemy 
import re

df = pd.read_csv("GSAF5.csv", encoding = "iso8859-1")

# %%
# changing column names

columns = "CaseNumber", "Date", "Year", "Type", "Country", "Area", "Location", "Activity", "Name", "Sex", "...", "Species", "Investigator or Source", "pdf", "href formula", "href", "Case Number.1","Case Number.2", "original order", "Unnamed: 22","Unnamed: 23"
ncolumns = "CaseNumber", "Date", "Year", "Type", "Country", "Area", "Location", "Activity", "Name", "Sex", "...", "Species", "Investigator or Source", "pdf", "href formula", "href", "Case Number.1","Case Number.2", "original order", "Unnamed: 22","Unnamed: 23"


New_df= df.rename(columns = {columns : ncolumns})

# %%
#drop nan columns 

New_df.dropna(how = "all", axis='columns')
New_df.dropna(thresh=2)
New_df.dropna(subset=["Date", "Year", "Type", "Country", "Area", "Location", "Activity"])
New_df = New_df.replace(0, pd.np.nan).dropna(axis=0, how='any', subset=["Date", "Year", "Type", "Country", "Area", "Location", "Activity"])
print(New_df)
# no complete nan columns
# Out:
#        Case Number                   Date    Year        Type  \
# 0     2016.09.18.c              18-Sep-16  2016.0  Unprovoked
# 1     2016.09.18.b              18-Sep-16  2016.0  Unprovoked
# 2     2016.09.18.a              18-Sep-16  2016.0  Unprovoked
# 3       2016.09.17              17-Sep-16  2016.0  Unprovoked
# 4       2016.09.15              16-Sep-16  2016.0  Unprovoked
# 5     2016.09.15.R              15-Sep-16  2016.0        Boat
# 6       2016.09.11              11-Sep-16  2016.0  Unprovoked
# 7       2016.09.07              07-Sep-16  2016.0  Unprovoked
# 8       2016.09.06              06-Sep-16  2016.0  Unprovoked
# 9     2016.09.05.b              05-Sep-16  2016.0  Unprovoked
# 10    2016.09.05.a              05-Sep-16  2016.0  Unprovoked
# 11      2016.09.04              04-Sep-16  2016.0  Unprovoked
# 12      2016.09.01              01-Sep-16  2016.0  Unprovoked
# 13    2016.08.29.b              29-Aug-16  2016.0  Unprovoked
# ...

# %%
#New_df.Year(dtype='int32')

#Years = df["Year"]
#deaths = df["Year"]

#plot = New_df.plot.scatter(x=,y=deaths)
print(New_df.plot.hist())
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)

# %%
#Countrycount = New_df["Country"]
Result = New_df.groupby("Country").agg({"Country":"count"})
Result
# Out:
#                             Country
# Country
#  TONGA                            3
# AMERICAN SAMOA                    3
# ANTIGUA                           1
# ARGENTINA                         1
# ATLANTIC OCEAN                    1
# AUSTRALIA                      1116
# BAHAMAS                          62
# BARBADOS                          4
# BELIZE                            1
# BERMUDA                           7
# BRAZIL                           89
# BRITISH ISLES                     1
# BRITISH NEW GUINEA                1
# BRITISH WEST INDIES               1
# BURMA                             2
# CANADA                           10
# CAPE VERDE                        1
# CARIBBEAN SEA                     1
# CAYMAN ISLANDS                    1
# CHILE                             5
# CHINA                             4
# COLUMBIA                          6
# COSTA RICA                        7
# CROATIA                          22
# CUBA                             34
# ...

# %%
Auto = pd.read_csv("https://pynative.com/wp-content/uploads/2019/01/Automobile_data.csv")
print(Auto.head())
print(Auto.tail())
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0
#     index     company body-style  wheel-base  length engine-type  \
# 56     81  volkswagen      sedan        97.3   171.7         ohc
# 57     82  volkswagen      sedan        97.3   171.7         ohc
# ...

# %%
Auto = pd.read_csv("https://pynative.com/wp-content/uploads/2019/01/Automobile_data.csv", na_values={
"price":["?","n.a"],
'stroke':["?","n.a"],
'horsepower':["?","n.a"],
'peak-rpm':["?","n.a"],
'average-mileage':["?","n.a"]})
Auto.head()
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %%
Highest_price = Auto[['company','price']][df.price==df['price'].max()]
print(Highest_price)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-c150b4ba6717> in <module>
# ----> 1 Highest_price = Auto[['company','price']][df.price==df['price'].max()]
#       2 print(Highest_price)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'price'
